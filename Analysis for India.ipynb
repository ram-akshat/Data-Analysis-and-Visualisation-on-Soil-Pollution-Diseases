# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/soil_pollution_diseases.csv')

# %%
df
# Out:
#           Case_ID Date_Reported         Region    Country Pollutant_Type  \
# 0     CASE_100000    2024-09-12         Africa   Pakistan           Lead
# 1     CASE_100001    2024-01-01         Africa    Germany           Lead
# 2     CASE_100002    2025-02-24         Europe    Germany           Lead
# 3     CASE_100003    2024-09-24           Asia        USA           Lead
# 4     CASE_100004    2023-05-24         Africa      India       Chromium
# ...           ...           ...            ...        ...            ...
# 2995  CASE_102995    2024-04-08           Asia     Mexico        Mercury
# 2996  CASE_102996    2024-12-28           Asia  Australia     Pesticides
# 2997  CASE_102997    2023-07-15         Europe      India       Chromium
# 2998  CASE_102998    2024-07-30           Asia        USA           Lead
# 2999  CASE_102999    2024-09-04  North America      China        Cadmium
#
#       Pollutant_Concentration_mg_kg  Soil_pH  Temperature_C  Humidity_%  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Case_ID                        3000 non-null   object
#  1   Date_Reported                  3000 non-null   object
#  2   Region                         3000 non-null   object
#  3   Country                        3000 non-null   object
#  4   Pollutant_Type                 3000 non-null   object
#  5   Pollutant_Concentration_mg_kg  3000 non-null   float64
#  6   Soil_pH                        3000 non-null   float64
#  7   Temperature_C                  3000 non-null   float64
#  8   Humidity_%                     3000 non-null   float64
#  9   Rainfall_mm                    3000 non-null   float64
#  10  Crop_Type                      3000 non-null   object
#  11  Farming_Practice               3000 non-null   object
# ...

# %%
df["Country"].value_counts()
# Out:
# Country
# China        319
# USA          317
# Mexico       314
# India        311
# Nigeria      309
# Pakistan     305
# Brazil       293
# Germany      283
# Australia    278
# Kenya        271
# Name: count, dtype: int64

# %%
df_india=df[df["Country"]=="India"]

# %%
df_india
# Out:
#           Case_ID Date_Reported         Region Country Pollutant_Type  \
# 4     CASE_100004    2023-05-24         Africa   India       Chromium
# 11    CASE_100011    2023-07-07           Asia   India        Cadmium
# 19    CASE_100019    2023-11-17         Africa   India        Mercury
# 23    CASE_100023    2024-06-15           Asia   India        Mercury
# 33    CASE_100033    2023-10-02         Europe   India           Lead
# ...           ...           ...            ...     ...            ...
# 2966  CASE_102966    2023-11-06         Africa   India        Mercury
# 2971  CASE_102971    2023-07-20         Europe   India        Arsenic
# 2982  CASE_102982    2024-04-04         Europe   India        Cadmium
# 2991  CASE_102991    2025-03-02  South America   India       Chromium
# 2997  CASE_102997    2023-07-15         Europe   India       Chromium
#
#       Pollutant_Concentration_mg_kg  Soil_pH  Temperature_C  Humidity_%  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df["Pollutant_Type"],y=df["Pollutant_Concentration_mg_kg"])
# Out:
# <Axes: xlabel='Pollutant_Type', ylabel='Pollutant_Concentration_mg_kg'>

# %%
sns.barplot(x=df_india["Pollutant_Type"],y=df_india["Pollutant_Concentration_mg_kg"])
# Out:
# <Axes: xlabel='Pollutant_Type', ylabel='Pollutant_Concentration_mg_kg'>

# %%
sns.barplot(x=df_india["Disease_Type"],y=df_india["Pollutant_Concentration_mg_kg"])
# Out:
# <Axes: xlabel='Disease_Type', ylabel='Pollutant_Concentration_mg_kg'>

# %%
sns.countplot(x='Disease_Type', data=df_india)
# Out:
# <Axes: xlabel='Disease_Type', ylabel='count'>

# %%
sns.countplot(x='Disease_Severity', data=df_india)
# Out:
# <Axes: xlabel='Disease_Severity', ylabel='count'>

# %%
sns.pairplot(df_india)

# %%
ct = pd.crosstab(df_india['Disease_Type'], df_india['Disease_Severity'])
sns.heatmap(ct, annot=True, fmt='d', cmap='Blues')
# Out:
# <Axes: xlabel='Disease_Severity', ylabel='Disease_Type'>

# %%
ct = pd.crosstab(df_india['Disease_Type'], df_india['Health_Symptoms'])
sns.heatmap(ct, annot=True, fmt='d', cmap='Blues')
# Out:
# <Axes: xlabel='Health_Symptoms', ylabel='Disease_Type'>

# %%
ct = pd.crosstab(df_india['Disease_Type'], df_india['Pollutant_Type'])
sns.heatmap(ct, annot=True, fmt='d', cmap='Blues')
# Out:
# <Axes: xlabel='Pollutant_Type', ylabel='Disease_Type'>

# %%
ct = pd.crosstab(df_india['Disease_Severity'], df_india['Pollutant_Type'])
sns.heatmap(ct, annot=True, fmt='d', cmap='Blues')
# Out:
# <Axes: xlabel='Pollutant_Type', ylabel='Disease_Severity'>

# %% [markdown]
# we saw the impacts on india cadmium and pesticides are used highly
# we saw which poullutants cause which type of disease and how serious is that disease
